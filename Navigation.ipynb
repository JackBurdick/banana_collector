# %%
from unityagents import UnityEnvironment
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %% [markdown]
# ### Import Trainer
#
# The trainer uses:
#  - an Agent from ./agent.py
#  - DuelingQNetwork from ./model.py
#
# Information on the environment can be found in [unity_instructions](./unity_instructions.md)

# %%
from trainer import Trainer

# %%
t = Trainer()
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
## train agent
scores = t.train()
print(f"done")
# Out:
# Episode 100	Average Score: 0.8080
# Episode 200	Average Score: 3.7373
# Episode 300	Average Score: 8.1818
# Episode 400	Average Score: 9.89893
# Episode 500	Average Score: 12.0101
# Episode 600	Average Score: 12.5353
# Episode 700	Average Score: 12.2121
# Episode 800	Average Score: 14.5151
# Episode 841, 	Average Score: 15.03
# Env solved in 841 episodes!	Avg Score: 15.03
# params saved: ./params/best_params_15.pth
# done

# %%
# perserve score log
with open("scores.pkl", "wb") as f:
    pickle.dump(scores, f)

# %%
t.cleanup()
# Out:
# env closed

# %% [markdown]
# ## Plot Scores

# %%
with open("scores.pkl", "rb") as f:
    scores = pickle.load(f)

# %%
plt.plot(scores)

# %% [markdown]
# ### Plot smoothed scores

# %%
WINDOW_N = 20
smooth = np.convolve(scores, np.ones(WINDOW_N)/WINDOW_N, mode='valid')
plt.plot(smooth)
